# %% [markdown]
# Read write append create
# https://codeshare.io/a3wWJ1

# %%
file = open('demo.txt',"r")

# %%
print(file.readlines())

# %%
file.close()

# %%
with open('demo.txt','r') as file:
    print(file.read())

# %%
file = open('demo.txt',"w")
file.write("hee  hee hheee")
file.close()

# %%
file = open('file.txt','w')
file.write("kkkkkkkk")
file.close()

# %%
file = open('file.txt','a')
file.write("aaaaaaa")
file.close()

# %%
file = open('file2.txt','x')
file.write("aaaaaaa")

# %%
file.close()
