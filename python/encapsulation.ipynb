# %% [markdown]
# Encapsulation :

# %%
class Company:
    campany_name = "upflairss" #public variable
    company_add = "jaipur"      # public variable
    __company_acc= 446464545    #private var
    def show_private(self):
        print(self.__company_acc)
c = Company()
print(c.campany_name)
c.show_private()
# print(c.__company_acc) # accessing private var so error
# Out:
# upflairss
# 446464545

# %%
c._Company__company_acc
# Out:
# 446464545
