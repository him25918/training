# %% [markdown]
# | Exception                | Description                                 |
# | ------------------------ | ------------------------------------------- |
# | `SyntaxError`            | Invalid Python syntax                       |
# | `IndentationError`       | Incorrect indentation                       |
# | `NameError`              | Variable not defined                        |
# | `TypeError`              | Operation on incompatible data types        |
# | `ValueError`             | Correct type but invalid value              |
# | `IndexError`             | List index out of range                     |
# | `KeyError`               | Dictionary key not found                    |
# | `AttributeError`         | Object has no such attribute                |
# | `ImportError`            | Module import failed                        |
# | `ModuleNotFoundError`    | Module does not exist                       |
# | `FileNotFoundError`      | File does not exist                         |
# | `IOError`                | Input/output operation failed               |
# | `OSError`                | Operating system related error              |
# | `ZeroDivisionError`      | Division by zero                            |
# | `OverflowError`          | Result too large to handle                  |
# | `MemoryError`            | Out of memory                               |
# | `RuntimeError`           | Generic runtime error                       |
# | `RecursionError`         | Maximum recursion depth exceeded            |
# | `AssertionError`         | Assertion statement failed                  |
# | `EOFError`               | End of file reached unexpectedly            |
# | `KeyboardInterrupt`      | User interrupted program (`Ctrl + C`)       |
# | `StopIteration`          | Iterator has no more items                  |
# | `NotImplementedError`    | Method not implemented                      |
# | `PermissionError`        | Permission denied                           |
# | `TimeoutError`           | Operation timed out                         |
# | `ConnectionError`        | Network connection problem                  |
# | `ConnectionAbortedError` | Connection aborted                          |
# | `ConnectionRefusedError` | Connection refused                          |
# | `ConnectionResetError`   | Connection reset                            |
# | `BrokenPipeError`        | Broken pipe connection                      |
# | `UnboundLocalError`      | Local variable referenced before assignment |
# | `UnicodeError`           | Unicode-related error                       |
# | `UnicodeEncodeError`     | Encoding failed                             |
# | `UnicodeDecodeError`     | Decoding failed                             |
# | `UnicodeTranslateError`  | Translation failed                          |
# | `FloatingPointError`     | Floating-point operation failed             |
# | `ArithmeticError`        | Base class for arithmetic errors            |
# | `LookupError`            | Base class for lookup errors                |
# | `ReferenceError`         | Weak reference no longer exists             |
# | `SystemError`            | Internal interpreter error                  |
# | `SystemExit`             | Program exited using `sys.exit()`           |

# %%
try:
    pass
except:
    pass
else:
    pass
finally:
    pass

# try chalega toh else aur finally chalenge
# agr try me error toh except aur finally chalenge
# try sahi raha toh else chalega aur finally hamesha chalega

# ZeroDivisionError
# ValueError
# TypeError
#  IndexError

# %%
try:
    a = int(input("enter num1 : "))
    b = int(input("Enter num2 : "))
    print(a/b)
except ZeroDivisionError as e:
    print("ZeroDivisionError :- ",e)
except ValueError as e:
    print(e)
except TypeError as e:
    print(e)
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'hhh'

# %%
class InvalidAgeError(Exception):
    pass
try:
    age = 18
    if age<18:
        raise InvalidAgeError("you cannot vote")
    else:
        print("you can vote")
except InvalidAgeError as e:
    print(e)
# Out:
# you can vote

# %%
class InvalidMail(Exception):
    pass

email =
