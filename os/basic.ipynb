# %% [markdown]
# OS

# %%
import os

# %%
curr_dirr = os.getcwd()  # returns current working directory
curr_dirr
# Out:
# 'c:\\Users\\omprk\\OneDrive\\Desktop\\training\\os'

# %%
os.listdir(r'c:\\Users\\omprk\\OneDrive\\Desktop\\training') # it return the file or folder name in the dirr
# Out:
# ['.git',
#  '.gitattributes',
#  '.vscode',
#  'assignment',
#  'demo.ipynb',
#  'os',
#  'python']

# %%
os.mkdir("folder") # create a folder in the cwd

# %%
os.makedirs(r"abc\xyz\vud")  # create multiple subfolders

# %%
os.rename("folder","file") # rename the folder

# %%
os.chdir(r"c:\\Users\\omprk") # to change the cwd

# %%
os.getcwd()
# Out:
# 'c:\\Users\\omprk\\OneDrive\\Desktop\\training\\os'

# %%
os.path.isfile(r"C:\Users\omprk\OneDrive\Desktop\training\os\basic.ipynb") # checks if the path is file or not
# Out:
# True

# %%
os.path.isdir(r"C:\Users\omprk\OneDrive\Desktop\training\os\file") # checks if it is a directory or not
# Out:
# True
